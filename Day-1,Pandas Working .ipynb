# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\users\syed daud ali\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df=pd.read_csv("students.csv")

# %%
df.head(3)
# Out:
#     Student Code  Degree  Student Name  Mid  Quiz 1  Quiz 2  Best of Quizzes  \
# 0   022-14-19987  BS(CS)   Abdul Basit   28     8.0     3.0                8
# 1  022-14-110233  BS(CS)   Adeel Ahmed   17     NaN     5.0                5
# 2  022-14-110585  BS(CS)  Afrah Zareen   18     5.0     2.0                5
#
#    Assignment 1  Assignment 2  Best of Assignments  Total Sessional (50)  \
# 0           7.0           9.0                    9                    45
# 1           8.0          10.0                   10                    32
# 2           8.0          10.0                   10                    33
#
#    Final (50)  Total (100) Grade
# 0        25.0           70     B
# 1        18.0           50     F
# 2        30.0           63     C

# %%
df.tail(3)
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 45                9           9.0           NaN                    9
# 46                8           8.0          10.0                   10
# 47                9           5.0           7.0                    7
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 45                    45        35.0           80     A
# 46                    43        22.0           65     C
# 47                    27        19.0           46     F

# %%
df.sample(3)
# Out:
#      Student Code  Degree    Student Name  Mid  Quiz 1  Quiz 2  \
# 18  022-14-110223  BS(CS)   Madiha Jabeen   16     5.0     2.0
# 8   022-14-110601  BS(CS)  Areesha Sohail   19     9.0     4.0
# 14  022-14-110389  BS(CS)   Hareem Afshan   21     7.0     4.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 18                5           8.0          10.0                   10
# 8                 9           7.0           9.0                    9
# 14                7           6.0           8.0                    8
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 18                    31        29.0           60     C
# 8                     37        24.0           61     C
# 14                    36        29.0           65     C

# %%
df.shape
# Out:
# (48, 14)

# %%
df.describe()
# Out:
#              Mid     Quiz 1     Quiz 2  Best of Quizzes  Assignment 1  \
# count  48.000000  45.000000  45.000000        48.000000     45.000000
# mean   22.937500   7.288889   4.866667         7.020833      7.755556
# std     5.236558   1.561209   1.455397         1.973113      1.170772
# min     9.000000   4.000000   1.000000         0.000000      5.000000
# 25%    20.000000   6.000000   4.000000         6.000000      7.000000
# 50%    25.000000   8.000000   5.000000         7.000000      8.000000
# 75%    27.000000   9.000000   6.000000         9.000000      8.000000
# max    30.000000   9.000000   7.000000         9.000000     10.000000
#
#        Assignment 2  Best of Assignments  Total Sessional (50)  Final (50)  \
# count     36.000000            48.000000             48.000000   47.000000
# mean       9.444444             8.937500             38.895833   27.851064
# std        1.629100             2.127892              7.179283    8.431253
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student Code          48 non-null     object
#  1   Degree                48 non-null     object
#  2   Student Name          48 non-null     object
#  3   Mid                   48 non-null     int64
#  4   Quiz 1                45 non-null     float64
#  5   Quiz 2                45 non-null     float64
#  6   Best of Quizzes       48 non-null     int64
#  7   Assignment 1          45 non-null     float64
#  8   Assignment 2          36 non-null     float64
#  9   Best of Assignments   48 non-null     int64
#  10  Total Sessional (50)  48 non-null     int64
#  11  Final (50)            47 non-null     float64
#  12  Total (100)           48 non-null     int64
#  13  Grade                 48 non-null     object
# dtypes: float64(5), int64(5), object(4)
# ...

# %%
df.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
df.T
# Out:
#                                 0              1              2   \
# Student Code          022-14-19987  022-14-110233  022-14-110585
# Degree                      BS(CS)         BS(CS)         BS(CS)
# Student Name           Abdul Basit    Adeel Ahmed   Afrah Zareen
# Mid                             28             17             18
# Quiz 1                         8.0            NaN            5.0
# Quiz 2                         3.0            5.0            2.0
# Best of Quizzes                  8              5              5
# Assignment 1                   7.0            8.0            8.0
# Assignment 2                   9.0           10.0           10.0
# Best of Assignments              9             10             10
# Total Sessional (50)            45             32             33
# Final (50)                    25.0           18.0           30.0
# Total (100)                     70             50             63
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=48, step=1),
#  Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#         'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#         'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#         'Total (100)', 'Grade'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# Student Code             object
# Degree                   object
# Student Name             object
# Mid                       int64
# Quiz 1                  float64
# Quiz 2                  float64
# Best of Quizzes           int64
# Assignment 1            float64
# Assignment 2            float64
# Best of Assignments       int64
# Total Sessional (50)      int64
# Final (50)              float64
# Total (100)               int64
# Grade                    object
# dtype: object
